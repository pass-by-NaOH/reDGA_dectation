# %%
from utils import *

# 加载数据
filename = 'data/dga_domains_sample.csv'
file_dataframe = read_file(filename)
# 1表示DGA域名 0表示正常合法域名
file_dataframe.head()
# Out:
# Bad key "text.kerning_factor" on line 4 in
# D:\IDE\Anaconda\conda\envs\tensorflow\lib\site-packages\matplotlib\mpl-data\stylelib\_classic_test_patch.mplstyle.
# You probably need to get an updated matplotlibrc file from
# https://github.com/matplotlib/matplotlib/blob/v3.1.3/matplotlibrc.template
# or from the matplotlib source distribution
#                     Domain  Label
# 0  cvyh1po636avyrsxebwbkn7      1
# 1              plasticbags      0
# 2                 mzltrack      0
# 3                miss-slim      0
# 4           txumyqrubwutbb      1

# %%
# 数据向量化
import nltk

list_Domain = file_dataframe['Domain'].tolist()
list_Label = file_dataframe['Label'].tolist()

# 生成2-gram, 3-gram, 4-gram
biGram = [generate_ngrams(domain, 2) for domain in list_Domain]
triGram = [generate_ngrams(domain, 3) for domain in list_Domain]
forthGram = [generate_ngrams(domain, 4) for domain in list_Domain]

# n-gram，由于DGA域名和
# Out:
# cvyh1po636avyrsxebwbkn7: 2-gram: ['cv', 'vy', 'yh', 'h1', '1p', 'po', 'o6', '63', '36', '6a', 'av', 'vy', 'yr', 'rs', 'sx', 'xe', 'eb', 'bw', 'wb', 'bk', 'kn', 'n7'], 3-gram: ['cvy', 'vyh', 'yh1', 'h1p', '1po', 'po6', 'o63', '636', '36a', '6av', 'avy', 'vyr', 'yrs', 'rsx', 'sxe', 'xeb', 'ebw', 'bwb', 'wbk', 'bkn', 'kn7'], 4-gram: ['cvyh', 'vyh1', 'yh1p', 'h1po', '1po6', 'po63', 'o636', '636a', '36av', '6avy', 'avyr', 'vyrs', 'yrsx', 'rsxe', 'sxeb', 'xebw', 'ebwb', 'bwbk', 'wbkn', 'bkn7']
# plasticbags: 2-gram: ['pl', 'la', 'as', 'st', 'ti', 'ic', 'cb', 'ba', 'ag', 'gs'], 3-gram: ['pla', 'las', 'ast', 'sti', 'tic', 'icb', 'cba', 'bag', 'ags'], 4-gram: ['plas', 'last', 'asti', 'stic', 'ticb', 'icba', 'cbag', 'bags']
# mzltrack: 2-gram: ['mz', 'zl', 'lt', 'tr', 'ra', 'ac', 'ck'], 3-gram: ['mzl', 'zlt', 'ltr', 'tra', 'rac', 'ack'], 4-gram: ['mzlt', 'zltr', 'ltra', 'trac', 'rack']
# ...
